# %% [markdown]
# # Machine Learning - Chapter 15
#
# # Dimensionality Reduction (PCA, LDA, t-SNE)
#
# Dimensionality Reduction reduces the number of input features while trying to preserve important information.
#
# It helps with visualization, speed, noise reduction, and sometimes model performance.

# %% [markdown]
# # PCA
#
# Principal Component Analysis is an unsupervised dimensionality reduction technique.
#
# PCA creates new features called **principal components** that capture maximum variance in the data.

# %% [markdown]
# # LDA and t-SNE
#
# **LDA** is supervised and tries to find directions that separate classes well.
#
# **t-SNE** is mainly used for visualizing high-dimensional data in 2D or 3D. It is good for exploration but not usually used as a general preprocessing step for production models.

# %% [markdown]
# # Python Implementation
#
# The following cells show a small practical example for this chapter.

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.manifold import TSNE

# %%
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = iris.target

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print('Explained variance ratio:', pca.explained_variance_ratio_)

plt.figure(figsize=(6, 5))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.title('PCA Visualization')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %%
lda = LinearDiscriminantAnalysis(n_components=2)
X_lda = lda.fit_transform(X_scaled, y)

plt.figure(figsize=(6, 5))
plt.scatter(X_lda[:, 0], X_lda[:, 1], c=y, cmap='viridis')
plt.title('LDA Visualization')
plt.xlabel('LD1')
plt.ylabel('LD2')
plt.show()

# %%
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

plt.figure(figsize=(6, 5))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis')
plt.title('t-SNE Visualization')
plt.show()

# %% [markdown]
# # Advantages / Uses
#
# - Helps solve real machine learning problems.
# - Gives a practical tool for analysis, prediction, or automation.
# - Can be combined with preprocessing, evaluation, and deployment workflows.

# %% [markdown]
# # Limitations / Things to Remember
#
# - Performance depends heavily on data quality.
# - Always evaluate on unseen data when labels are available.
# - Check assumptions, leakage, bias, and production constraints.

# %% [markdown]
# # Practice Questions
#
# 1. Why reduce dimensionality?
# 2. What does PCA maximize?
# 3. How is LDA different from PCA?
# 4. Why is t-SNE mostly used for visualization?

# %% [markdown]
# # Chapter Summary
#
# - Dimensionality reduction reduces feature count.
# - PCA is unsupervised and preserves variance.
# - LDA is supervised and focuses on class separation.
# - t-SNE is useful for visualization.
